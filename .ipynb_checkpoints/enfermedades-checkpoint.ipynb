# %%
library(tidyverse)
library(dslabs)
library(dplyr)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.4
# ✔ tidyr   1.0.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
mortalidad <- read_csv("/home/rtorrealba/learningR/data/mortalidad_cl.csv")
data(mortalidadcl)
mortalidad
# Out:
# Parsed with column specification:
# cols(
#   `ID CIE 10` = col_character(),
#   `CIE 10` = col_character(),
#   `ID Year` = col_double(),
#   Year = col_double(),
#   `Casualities Count SUM` = col_double(),
#   `Casualities rate per 100 inhabitants` = col_double()
# )
#
# Warning message in data(mortalidadcl):
# “data set ‘mortalidadcl’ not found”
#    ID CIE 10 CIE 10                                               ID Year Year
# 1  B20-B24   Infecciones por VIH y SIDA                           2010    2010
# 2  B20-B24   Infecciones por VIH y SIDA                           2011    2011
# 3  B20-B24   Infecciones por VIH y SIDA                           2012    2012
# 4  B20-B24   Infecciones por VIH y SIDA                           2013    2013
# 5  B20-B24   Infecciones por VIH y SIDA                           2014    2014
# 6  C00-D48   Tumores (neoplasias)                                 2010    2010
# 7  C00-D48   Tumores (neoplasias)                                 2011    2011
# 8  C00-D48   Tumores (neoplasias)                                 2012    2012
# 9  C00-D48   Tumores (neoplasias)                                 2013    2013
# 10 C00-D48   Tumores (neoplasias)                                 2014    2014
# 11 E00-E90   Enfermedades endocrinas, nutricionales y metabolicas 2010    2010
# 12 E00-E90   Enfermedades endocrinas, nutricionales y metabolicas 2011    2011
# 13 E00-E90   Enfermedades endocrinas, nutricionales y metabolicas 2012    2012
# 14 E00-E90   Enfermedades endocrinas, nutricionales y metabolicas 2013    2013
# 15 E00-E90   Enfermedades endocrinas, nutricionales y metabolicas 2014    2014
# 16 I00-I99   Enfermedades del sistema circulatorio                2010    2010
# 17 I00-I99   Enfermedades del sistema circulatorio                2011    2011
# 18 I00-I99   Enfermedades del sistema circulatorio                2012    2012
# 19 I00-I99   Enfermedades del sistema circulatorio                2013    2013
# 20 I00-I99   Enfermedades del sistema circulatorio                2014    2014
# 21 J00-J99   Enfermedades del sistema respiratorio                2010    2010
# 22 J00-J99   Enfermedades del sistema respiratorio                2011    2011
# 23 J00-J99   Enfermedades del sistema respiratorio                2012    2012
# 24 J00-J99   Enfermedades del sistema respiratorio                2013    2013
# 25 J00-J99   Enfermedades del sistema respiratorio                2014    2014
# 26 K00-K93   Enfermedades del sistema digestivo                   2010    2010
# 27 K00-K93   Enfermedades del sistema digestivo                   2011    2011
# 28 K00-K93   Enfermedades del sistema digestivo                   2012    2012
# 29 K00-K93   Enfermedades del sistema digestivo                   2013    2013
# 30 K00-K93   Enfermedades del sistema digestivo                   2014    2014
# 31 V01-V99   Accidentes de tránsito                               2010    2010
# 32 V01-V99   Accidentes de tránsito                               2011    2011
# 33 V01-V99   Accidentes de tránsito                               2012    2012
# 34 V01-V99   Accidentes de tránsito                               2013    2013
# 35 V01-V99   Accidentes de tránsito                               2014    2014
# 36 V01-Y98   Causa Externa de mortalidad                          2010    2010
# 37 V01-Y98   Causa Externa de mortalidad                          2011    2011
# 38 V01-Y98   Causa Externa de mortalidad                          2012    2012
# 39 V01-Y98   Causa Externa de mortalidad                          2013    2013
# 40 V01-Y98   Causa Externa de mortalidad                          2014    2014
# 41 X60-X84   Lesiones autoinfligidas intencionalmente             2010    2010
# 42 X60-X84   Lesiones autoinfligidas intencionalmente             2011    2011
# 43 X60-X84   Lesiones autoinfligidas intencionalmente             2012    2012
# 44 X60-X84   Lesiones autoinfligidas intencionalmente             2013    2013
# 45 X60-X84   Lesiones autoinfligidas intencionalmente             2014    2014
#    Casualities Count SUM Casualities rate per 100 inhabitants
# 1    435                 0.02414000
# 2    472                 0.02830000
# 3    456                 0.02661000
# 4    523                 0.02719667
# 5    506                 0.02952333
# 6  24088                 1.39447333
# 7  24582                 1.43264001
# 8  25421                 1.46909666
# 9  25687                 1.44042333
# 10 26042                 1.46881334
# 11  4821                 0.27405000
# 12  4640                 0.25414333
# 13  4930                 0.27460667
# 14  4876                 0.25378000
# 15  5188                 0.27171000
# 16 27158                 1.53352666
# 17 25744                 1.45189000
# 18 27179                 1.55333334
# 19 27660                 1.50591334
# 20 28060                 1.49855332
# 21  9993                 0.60348333
# 22  9104                 0.52756000
# 23 10118                 0.57727333
# 24 10269                 0.56147333
# 25 10447                 0.55020000
# 26  7051                 0.41266334
# 27  6964                 0.40333333
# 28  7140                 0.39853333
# 29  7349                 0.42387666
# 30  7469                 0.41435333
# 31  2097                 0.13655000
# 32  2113                 0.15626000
# 33  2050                 0.14467000
# 34  2121                 0.14153000
# 35  1982                 0.12311000
# 36  8385                 0.53348000
# 37  8027                 0.53223333
# 38  7561                 0.49222667
# 39  7617                 0.47934000
# 40  7730                 0.46785000
# 41  1986                 0.12864333
# 42  2027                 0.12407333
# 43  1841                 0.11158667
# 44  1738                 0.10222000
# 45  1789                 0.10371667

# %%
 mortalidad %>%
    ggplot(aes(year, label = a2002, color = edad)) +
    geom_line()
# Out:
# ERROR while rich displaying an object: Error in FUN(X[[i]], ...): objeto 'year' no encontrado
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_text.default(obj)
# 9. paste(capture.output(print(obj)), collapse = "\n")
# 10. capture.output(print(obj))
# 11. evalVis(expr)
# 12. withVisible(eval(expr, pf))
# 13. eval(expr, pf)
# 14. eval(expr, pf)
# 15. print(obj)
# 16. print.ggplot(obj)
# 17. ggplot_build(x)
# 18. ggplot_build.ggplot(x)
# 19. by_layer(function(l, d) l$compute_aesthetics(d, plot))
# 20. f(l = layers[[i]], d = data[[i]])
# 21. l$compute_aesthetics(d, plot)
# 22. f(..., self = self)
# 23. scales_add_defaults(plot$scales, data, aesthetics, plot$plot_env)
# 24. lapply(aesthetics[new_aesthetics], eval_tidy, data = data)
# 25. FUN(X[[i]], ...)
# plot without title
