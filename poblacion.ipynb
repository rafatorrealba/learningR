# %%
library(tidyverse)
library(dslabs)
library(nycflights13, gapminder)
library(dplyr)

# %%
lapintana <- read_csv("/home/rtorrealba/learningR/data/lapintana.csv")
# Out:
# Parsed with column specification:
# cols(
#   Fecha = col_double(),
#   Hombres = col_double(),
#   Mujeres = col_double()
# )

# %%
lapintana
# Out:
#    Fecha Hombres Mujeres
# 1  2005  2029    1943
# 2  2006  1999    1944
# 3  2007  2008    1766
# 4  2008  1960    1770
# 5  2009  1865    1747
# 6  2010  1772    1602
# 7  2011  1749    1744
# 8  2012  1855    1721
# 9  2013  1868    1758
# 10 2014  1671    1638

# %%
ggplot(data = lapintana) +
  geom_label(mapping = aes(x = Fecha, y = Hombres, label = Hombres))
# Out:
# plot without title

# %%
ggplot(data = lapintana) +
  geom_line(mapping = aes(x = Fecha, y = Hombres))
# Out:
# plot without title

# %%
ggplot(data = lapintana) +
  geom_label(mapping = aes(x = Fecha, y = Mujeres, label = Mujeres))
# Out:
# plot without title

# %%
ggplot(data = lapintana) +
  geom_line(mapping = aes(x = Fecha, y = Mujeres))
# Out:
# plot without title

# %%
proyeccion <- read_csv("/home/rtorrealba/learningR/data/proyeccion.csv")
# Out:
# Parsed with column specification:
# cols(
#   Edad = col_double(),
#   EdadR = col_character(),
#   `ID Sex` = col_double(),
#   Sexo = col_character(),
#   `ID Year` = col_double(),
#   Year = col_double(),
#   Population = col_double()
# )

# %%
proyeccion
# Out:
#     Edad EdadR    ID Sex Sexo      ID Year Year Population
# 1   1    0 a 4    1      Femenino  2005    2005 607264
# 2   1    0 a 4    1      Femenino  2006    2006 608314
# 3   1    0 a 4    1      Femenino  2007    2007 609364
# 4   1    0 a 4    1      Femenino  2008    2008 610414
# 5   1    0 a 4    1      Femenino  2009    2009 611465
# 6   1    0 a 4    1      Femenino  2010    2010 612515
# 7   1    0 a 4    1      Femenino  2011    2011 613598
# 8   1    0 a 4    1      Femenino  2012    2012 614681
# 9   1    0 a 4    1      Femenino  2013    2013 615764
# 10  1    0 a 4    1      Femenino  2014    2014 616848
# 11  1    0 a 4    1      Femenino  2015    2015 617931
# 12  1    0 a 4    1      Femenino  2016    2016 616534
# 13  1    0 a 4    1      Femenino  2017    2017 615138
# 14  1    0 a 4    1      Femenino  2018    2018 613741
# 15  1    0 a 4    1      Femenino  2019    2019 612345
# 16  1    0 a 4    1      Femenino  2020    2020 610948
# 17  1    0 a 4    2      Masculino 2005    2005 630199
# 18  1    0 a 4    2      Masculino 2006    2006 631321
# 19  1    0 a 4    2      Masculino 2007    2007 632443
# 20  1    0 a 4    2      Masculino 2008    2008 633566
# 21  1    0 a 4    2      Masculino 2009    2009 634688
# 22  1    0 a 4    2      Masculino 2010    2010 635810
# 23  1    0 a 4    2      Masculino 2011    2011 636963
# 24  1    0 a 4    2      Masculino 2012    2012 638116
# 25  1    0 a 4    2      Masculino 2013    2013 639270
# 26  1    0 a 4    2      Masculino 2014    2014 640423
# 27  1    0 a 4    2      Masculino 2015    2015 641576
# 28  1    0 a 4    2      Masculino 2016    2016 640150
# 29  1    0 a 4    2      Masculino 2017    2017 638724
# 30  1    0 a 4    2      Masculino 2018    2018 637299
# ⋮   ⋮    ⋮        ⋮      ⋮         ⋮       ⋮    ⋮
# 515 17   80 y más 1      Femenino  2007    2007 178761
# 516 17   80 y más 1      Femenino  2008    2008 186745
# 517 17   80 y más 1      Femenino  2009    2009 194730
# 518 17   80 y más 1      Femenino  2010    2010 202714
# 519 17   80 y más 1      Femenino  2011    2011 211089
# 520 17   80 y más 1      Femenino  2012    2012 219465
# 521 17   80 y más 1      Femenino  2013    2013 227840
# 522 17   80 y más 1      Femenino  2014    2014 236216
# 523 17   80 y más 1      Femenino  2015    2015 244591
# 524 17   80 y más 1      Femenino  2016    2016 252993
# 525 17   80 y más 1      Femenino  2017    2017 261395
# 526 17   80 y más 1      Femenino  2018    2018 269797
# 527 17   80 y más 1      Femenino  2019    2019 278198
# 528 17   80 y más 1      Femenino  2020    2020 286600
# 529 17   80 y más 2      Masculino 2005    2005  89871
# 530 17   80 y más 2      Masculino 2006    2006  94957
# 531 17   80 y más 2      Masculino 2007    2007 100042
# 532 17   80 y más 2      Masculino 2008    2008 105128
# 533 17   80 y más 2      Masculino 2009    2009 110213
# 534 17   80 y más 2      Masculino 2010    2010 115299
# 535 17   80 y más 2      Masculino 2011    2011 120623
# 536 17   80 y más 2      Masculino 2012    2012 125948
# 537 17   80 y más 2      Masculino 2013    2013 131272
# 538 17   80 y más 2      Masculino 2014    2014 136597
# 539 17   80 y más 2      Masculino 2015    2015 141921
# 540 17   80 y más 2      Masculino 2016    2016 147574
# 541 17   80 y más 2      Masculino 2017    2017 153228
# 542 17   80 y más 2      Masculino 2018    2018 158881
# 543 17   80 y más 2      Masculino 2019    2019 164534
# 544 17   80 y más 2      Masculino 2020    2020 170188

# %%
ggplot(data = proyeccion) +
  geom_label(mapping = aes(x = Year, y = Population, label = Edad))
# Out:
# plot without title

# %%
ggplot(data = proyeccion) +
  geom_point(mapping = aes(x = Year, y = Population))
# Out:
# plot without title

# %%
ggplot(data = proyeccion) +
  geom_point(mapping = aes(x = Year, y = ID Age Range))
# Out:
# Error in parse(text = x, srcfile = src): <text>:2:45: unexpected symbol
# 1: ggplot(data = proyeccion) +
# 2:   geom_point(mapping = aes(x = Year, y = ID Age
#                                                ^
# Traceback:
