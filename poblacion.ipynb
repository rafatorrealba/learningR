# %%
library(tidyverse)
library(dslabs)
library(nycflights13, gapminder)
library(dplyr)

# %%
data(Denuncias_delitos)

# %%
Denuncias_delitos
# Out:
#     ID.Crime.Group.Crime.Group.ID.Crime.Crime.ID.Year.Year.Cases
# 1   1,Robo,1,Robo con violencia o intimidación,2005,2005,54467.0
# 2   1,Robo,1,Robo con violencia o intimidación,2006,2006,56491.0
# 3   1,Robo,1,Robo con violencia o intimidación,2007,2007,65929.0
# 4   1,Robo,1,Robo con violencia o intimidación,2008,2008,61938.0
# 5   1,Robo,1,Robo con violencia o intimidación,2009,2009,61521.0
# 6   1,Robo,1,Robo con violencia o intimidación,2010,2010,53128.0
# 7   1,Robo,1,Robo con violencia o intimidación,2011,2011,61399.0
# 8   1,Robo,1,Robo con violencia o intimidación,2012,2012,54080.0
# 9   1,Robo,1,Robo con violencia o intimidación,2013,2013,57975.0
# 10  1,Robo,1,Robo con violencia o intimidación,2014,2014,59893.0
# 11  1,Robo,1,Robo con violencia o intimidación,2015,2015,67272.0
# 12  1,Robo,1,Robo con violencia o intimidación,2016,2016,65678.0
# 13  1,Robo,2,Robo por sorpresa,2005,2005,19972.0
# 14  1,Robo,2,Robo por sorpresa,2006,2006,21744.0
# ...

# %%
 poblacion_2002_2020 %>%
    ggplot(aes(a2002, edad, label = a2002, color = edad)) +
    geom_line()
# Out:
# plot without title

# %%
head(poblacion_2002_2020) %>%
    ggplot(aes(a2003, edad, label = a2003, color = edad)) +
    geom_line()
# Out:
# plot without title

# %%
head(poblacion_2002_2020) %>%
    ggplot(aes(a2005, edad, label = a2004, color = edad)) +
    geom_line()
# Out:
# plot without title

# %%
ggplot(data = Denuncias_delitos) + 
  geom_point(mapping = aes(x = Year, y = cases))
# Out:
# ERROR while rich displaying an object: Error in FUN(X[[i]], ...): objeto 'Year' no encontrado
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# ...
